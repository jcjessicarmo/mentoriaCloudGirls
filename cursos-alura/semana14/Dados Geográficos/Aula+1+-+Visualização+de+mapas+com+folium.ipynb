# %%
# !pip install geopandas==0.13.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas==0.13.2
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.7 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas==0.13.2)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 72.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas==0.13.2)
#   Downloading pyproj-3.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 93.1 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas==0.13.2)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas==0.13.2)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas==0.13.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas==0.13.2) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas==0.13.2) (1.22.4)
# Installing collected packages: pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 pyproj-3.6.0

# %%
import geopandas as gpd

# %% [markdown]
# ### Explorando os dados geográficos

# %%
rj = gpd.read_file('/content/drive/MyDrive/Alura/dados/imoveis/rj_setores_censitarios/33SEE250GC_SIR.shp')
rj
# Out:
#           ID       CD_GEOCODI    TIPO    CD_GEOCODB         NM_BAIRRO  \
# 0      43773  330025805000046  URBANO           NaN               NaN
# 1      43774  330025805000047  URBANO           NaN               NaN
# 2      43775  330025805000048  URBANO           NaN               NaN
# 3      43776  330025805000049  URBANO           NaN               NaN
# 4      43777  330025805000050  URBANO           NaN               NaN
# ...      ...              ...     ...           ...               ...
# 28313  72057  330630505000488  URBANO  330630505045        Três Poços
# 28314  72058  330630505000489  URBANO           NaN               NaN
# 28315  72059  330630505000490  URBANO           NaN               NaN
# 28316  72060  330630505000491  URBANO  330630505041     Vila Brasília
# 28317  72061  330630505000492  URBANO  330630505015  Jardim Belvedere
#
#         CD_GEOCODS NM_SUBDIST CD_GEOCODD       NM_DISTRIT CD_GEOCODM  \
# 0      33002580500        NaN  330025805  ARRAIAL DO CABO    3300258
# 1      33002580500        NaN  330025805  ARRAIAL DO CABO    3300258
# 2      33002580500        NaN  330025805  ARRAIAL DO CABO    3300258
# 3      33002580500        NaN  330025805  ARRAIAL DO CABO    3300258
# 4      33002580500        NaN  330025805  ARRAIAL DO CABO    3300258
# ...            ...        ...        ...              ...        ...
# 28313  33063050500        NaN  330630505    VOLTA REDONDA    3306305
# 28314  33063050500        NaN  330630505    VOLTA REDONDA    3306305
# 28315  33063050500        NaN  330630505    VOLTA REDONDA    3306305
# 28316  33063050500        NaN  330630505    VOLTA REDONDA    3306305
# 28317  33063050500        NaN  330630505    VOLTA REDONDA    3306305
#
#             NM_MUNICIP                    NM_MICRO         NM_MESO  \
# 0      ARRAIAL DO CABO                       LAGOS        BAIXADAS
# 1      ARRAIAL DO CABO                       LAGOS        BAIXADAS
# 2      ARRAIAL DO CABO                       LAGOS        BAIXADAS
# 3      ARRAIAL DO CABO                       LAGOS        BAIXADAS
# 4      ARRAIAL DO CABO                       LAGOS        BAIXADAS
# ...                ...                         ...             ...
# 28313    VOLTA REDONDA  VALE DO PARAÍBA FLUMINENSE  SUL FLUMINENSE
# 28314    VOLTA REDONDA  VALE DO PARAÍBA FLUMINENSE  SUL FLUMINENSE
# 28315    VOLTA REDONDA  VALE DO PARAÍBA FLUMINENSE  SUL FLUMINENSE
# 28316    VOLTA REDONDA  VALE DO PARAÍBA FLUMINENSE  SUL FLUMINENSE
# 28317    VOLTA REDONDA  VALE DO PARAÍBA FLUMINENSE  SUL FLUMINENSE
#
#                                                 geometry
# 0      POLYGON ((-42.01954 -22.96936, -42.02059 -22.9...
# 1      POLYGON ((-42.02282 -22.96769, -42.02290 -22.9...
# 2      POLYGON ((-42.16022 -22.94740, -42.16241 -22.9...
# 3      POLYGON ((-42.17397 -22.94625, -42.17588 -22.9...
# 4      POLYGON ((-42.17588 -22.94609, -42.17848 -22.9...
# ...                                                  ...
# 28313  POLYGON ((-44.03993 -22.49914, -44.04028 -22.4...
# 28314  POLYGON ((-44.08332 -22.61036, -44.08420 -22.6...
# 28315  POLYGON ((-44.08155 -22.60923, -44.08150 -22.6...
# 28316  POLYGON ((-44.11933 -22.48886, -44.11992 -22.4...
# 28317  POLYGON ((-44.06462 -22.53845, -44.06463 -22.5...
#
# [28318 rows x 14 columns]

# %%
rj.plot();

# %%
cidade_rio = rj[rj['NM_MUNICIP'] == 'RIO DE JANEIRO']
cidade_rio
# Out:
#           ID       CD_GEOCODI    TIPO    CD_GEOCODB        NM_BAIRRO  \
# 10708  56651  330455705080006  URBANO  330455705005          Catumbi
# 10709  56652  330455705080007  URBANO  330455705005          Catumbi
# 10710  56653  330455705080008  URBANO  330455705005          Catumbi
# 10711  56654  330455705080009  URBANO  330455705005          Catumbi
# 10712  56655  330455705080010  URBANO  330455705005          Catumbi
# ...      ...              ...     ...           ...              ...
# 23324  66988  330455705390224  URBANO  330455705044  Parada de Lucas
# 23325  66989  330455705390225  URBANO  330455705044  Parada de Lucas
# 23326  66990  330455705390226  URBANO  330455705043         Cordovil
# 23327  66991  330455705390227  URBANO  330455705043         Cordovil
# 23328  66992  330455705390228  URBANO  330455705043         Cordovil
#
#         CD_GEOCODS     NM_SUBDIST CD_GEOCODD      NM_DISTRIT CD_GEOCODM  \
# 10708  33045570508   RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
# 10709  33045570508   RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
# 10710  33045570508   RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
# 10711  33045570508   RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
# 10712  33045570508   RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
# ...            ...            ...        ...             ...        ...
# 23324  33045570539  VIGÁRIO GERAL  330455705  RIO DE JANEIRO    3304557
# 23325  33045570539  VIGÁRIO GERAL  330455705  RIO DE JANEIRO    3304557
# 23326  33045570539  VIGÁRIO GERAL  330455705  RIO DE JANEIRO    3304557
# 23327  33045570539  VIGÁRIO GERAL  330455705  RIO DE JANEIRO    3304557
# 23328  33045570539  VIGÁRIO GERAL  330455705  RIO DE JANEIRO    3304557
#
#            NM_MUNICIP        NM_MICRO                          NM_MESO  \
# 10708  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 10709  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 10710  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 10711  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 10712  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# ...               ...             ...                              ...
# 23324  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 23325  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 23326  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 23327  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
# 23328  RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO
#
#                                                 geometry
# 10708  POLYGON ((-43.19949 -22.92454, -43.19953 -22.9...
# 10709  POLYGON ((-43.19795 -22.91829, -43.19819 -22.9...
# 10710  POLYGON ((-43.19858 -22.91876, -43.19888 -22.9...
# 10711  POLYGON ((-43.19879 -22.91937, -43.19879 -22.9...
# 10712  POLYGON ((-43.19791 -22.92028, -43.19791 -22.9...
# ...                                                  ...
# 23324  POLYGON ((-43.29433 -22.81438, -43.29466 -22.8...
# 23325  POLYGON ((-43.29344 -22.81420, -43.29368 -22.8...
# 23326  POLYGON ((-43.29526 -22.81908, -43.29543 -22.8...
# 23327  POLYGON ((-43.30205 -22.82791, -43.30215 -22.8...
# 23328  POLYGON ((-43.28302 -22.81597, -43.28482 -22.8...
#
# [10504 rows x 14 columns]

# %%
cidade_rio.plot();

# %%
import folium

# %%
mapa_rio = folium.Map(location = [-22, -43],
                      zoom_start = 8)

mapa_rio
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d029be26c6a035df31a5e3e9cafc8de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d029be26c6a035df31a5e3e9cafc8de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d029be26c6a035df31a5e3e9cafc8de = L.map(
#                 &quot;map_6d029be26c6a035df31a5e3e9cafc8de&quot;,
#                 {
#                     center: [-22.0, -43.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abd7173885d89d93f87ba98386ab18af = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d029be26c6a035df31a5e3e9cafc8de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# O folium permite a utilização de diferentes tipos de representação de mapas:
#
# - OpenStreetMap
#
# - Mapbox Bright
#
# - Mapbox Control Room
#
# - Stamen (Terrain, Toner, e Watercolor)
#
# - Cloudmade
#
# - Mapbox
#
# - CartoDB (positron e dark_matter)
#
# Além disso, é possível usar uma representação customizada a partir de uma url do tipo: http://{s}.yourtiles.com/{z}/{x}/{y}.png.
#
# A lista completa pode de representações personalizadas pode ser encontrada no link: http://leaflet-extras.github.io/leaflet-providers/preview/.

# %%
mapa_rio = folium.Map(location = [-22, -43],
                      zoom_start = 8,
                      tiles = 'stamenterrain')

mapa_rio
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af750d095e9fb74d5835f9e157f76370 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af750d095e9fb74d5835f9e157f76370&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af750d095e9fb74d5835f9e157f76370 = L.map(
#                 &quot;map_af750d095e9fb74d5835f9e157f76370&quot;,
#                 {
#                     center: [-22.0, -43.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8228887f398bf7dd4e5310bd981dd6e2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_af750d095e9fb74d5835f9e157f76370);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa_rio = folium.Map(location = [-22, -43],
                      zoom_start = 8,
                      tiles = 'stamenterrain',
                      name = 'Stamen')

folium.TileLayer('cartodbpositron', name = 'Positron').add_to(mapa_rio)
folium.TileLayer('cartodbdark_matter', name = 'Dark').add_to(mapa_rio)
folium.TileLayer('https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png', name = 'OSM',
                 attr = '<a href="https://github.com/cyclosm/cyclosm-cartocss-style/releases" title="CyclOSM - Open Bicycle render">CyclOSM</a> | Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors').add_to(mapa_rio)

folium.LayerControl().add_to(mapa_rio)

mapa_rio.save('mapa_rio.html')

mapa_rio
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3123999369ab059fbddadadc84bd9c93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3123999369ab059fbddadadc84bd9c93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3123999369ab059fbddadadc84bd9c93 = L.map(
#                 &quot;map_3123999369ab059fbddadadc84bd9c93&quot;,
#                 {
#                     center: [-22.0, -43.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;Stamen&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50aec2e6703ca500e7bcc306535b32f0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3123999369ab059fbddadadc84bd9c93);
#
#
#             var tile_layer_d45eab378aec03c17cf854906fc868e3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3123999369ab059fbddadadc84bd9c93);
#
#
#             var tile_layer_848c7f99c96e2435a6221beeff7fd97c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3123999369ab059fbddadadc84bd9c93);
#
#
#             var tile_layer_8f57156ce45c5e1765b9b4b3e87c0bb6 = L.tileLayer(
#                 &quot;https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u003ca href=\&quot;https://github.com/cyclosm/cyclosm-cartocss-style/releases\&quot; title=\&quot;CyclOSM - Open Bicycle render\&quot;\u003eCyclOSM\u003c/a\u003e | Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3123999369ab059fbddadadc84bd9c93);
#
#
#             var layer_control_df6cdb1712287345bba398175ccf6d84 = {
#                 base_layers : {
#                     &quot;stamenterrain&quot; : tile_layer_50aec2e6703ca500e7bcc306535b32f0,
#                     &quot;Positron&quot; : tile_layer_d45eab378aec03c17cf854906fc868e3,
#                     &quot;Dark&quot; : tile_layer_848c7f99c96e2435a6221beeff7fd97c,
#                     &quot;OSM&quot; : tile_layer_8f57156ce45c5e1765b9b4b3e87c0bb6,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_df6cdb1712287345bba398175ccf6d84.base_layers,
#                 layer_control_df6cdb1712287345bba398175ccf6d84.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_3123999369ab059fbddadadc84bd9c93);
#             tile_layer_d45eab378aec03c17cf854906fc868e3.remove();
#             tile_layer_848c7f99c96e2435a6221beeff7fd97c.remove();
#             tile_layer_8f57156c

# %%
bairros_rio = cidade_rio.dissolve(by = 'NM_BAIRRO')
bairros_rio
# Out:
#                                                             geometry     ID  \
# NM_BAIRRO
# Abolição           POLYGON ((-43.30094 -22.89123, -43.30095 -22.8...  59926
# Acari              POLYGON ((-43.34222 -22.82782, -43.34253 -22.8...  65174
# Alto da Boa Vista  POLYGON ((-43.29429 -22.97967, -43.29421 -22.9...  58519
# Anchieta           POLYGON ((-43.41002 -22.83423, -43.41015 -22.8...  64367
# Andaraí            POLYGON ((-43.26797 -22.93775, -43.26729 -22.9...  58716
# ...                                                              ...    ...
# Vila Valqueire     POLYGON ((-43.36708 -22.89711, -43.36718 -22.8...  60902
# Vila da Penha      POLYGON ((-43.31551 -22.84892, -43.31559 -22.8...  60156
# Vista Alegre       POLYGON ((-43.31911 -22.83312, -43.31912 -22.8...  60196
# Zumbi              POLYGON ((-43.17551 -22.82380, -43.17553 -22.8...  63989
# Água Santa         POLYGON ((-43.31071 -22.91650, -43.31157 -22.9...  59847
#
#                         CD_GEOCODI    TIPO    CD_GEOCODB   CD_GEOCODS  \
# NM_BAIRRO
# Abolição           330455705170481  URBANO  330455705060  33045570517
# Acari              330455705300052  URBANO  330455705138  33045570530
# Alto da Boa Vista  330455705130289  URBANO  330455705031  33045570513
# Anchieta           330455705270062  URBANO  330455705125  33045570527
# Andaraí            330455705140165  URBANO  330455705034  33045570514
# ...                            ...     ...           ...          ...
# Vila Valqueire     330455705210219  URBANO  330455705091  33045570521
# Vila da Penha      330455705190061  URBANO  330455705064  33045570519
# Vista Alegre       330455705190101  URBANO  330455705065  33045570519
# Zumbi              330455705250006  URBANO  330455705110  33045570525
# Água Santa         330455705170393  URBANO  330455705057  33045570517
#
#                            NM_SUBDIST CD_GEOCODD      NM_DISTRIT CD_GEOCODM  \
# NM_BAIRRO
# Abolição                        MÉIER  330455705  RIO DE JANEIRO    3304557
# Acari                          PAVUNA  330455705  RIO DE JANEIRO    3304557
# Alto da Boa Vista              TIJUCA  330455705  RIO DE JANEIRO    3304557
# Anchieta                     ANCHIETA  330455705  RIO DE JANEIRO    3304557
# Andaraí                   VILA ISABEL  330455705  RIO DE JANEIRO    3304557
# ...                               ...        ...             ...        ...
# Vila Valqueire            JACAREPAGUÁ  330455705  RIO DE JANEIRO    3304557
# Vila da Penha                   IRAJÁ  330455705  RIO DE JANEIRO    3304557
# Vista Alegre                    IRAJÁ  330455705  RIO DE JANEIRO    3304557
# Zumbi              ILHA DO GOVERNADOR  330455705  RIO DE JANEIRO    3304557
# Água Santa                      MÉIER  330455705  RIO DE JANEIRO    3304557
#
#                        NM_MUNICIP        NM_MICRO  \
# NM_BAIRRO
# Abolição           RIO DE JANEIRO  RIO DE JANEIRO
# Acari              RIO DE JANEIRO  RIO DE JANEIRO
# Alto da Boa Vista  RIO DE JANEIRO  RIO DE JANEIRO
# Anchieta           RIO DE JANEIRO  RIO DE JANEIRO
# Andaraí            RIO DE JANEIRO  RIO DE JANEIRO
# ...                           ...             ...
# Vila Valqueire     RIO DE JANEIRO  RIO DE JANEIRO
# Vila da Penha      RIO DE JANEIRO  RIO DE JANEIRO
# Vista Alegre       RIO DE JANEIRO  RIO DE JANEIRO
# Zumbi              RIO DE JANEIRO  RIO DE JANEIRO
# Água Santa         RIO DE JANEIRO  RIO DE JANEIRO
#
#                                            NM_MESO
# NM_BAIRRO
# Abolição           METROPOLITANA DO RIO DE JANEIRO
# Acari              METROPOLITANA DO RIO DE JANEIRO
# Alto da Boa Vista  METROPOLITANA DO RIO DE JANEIRO
# Anchieta           METROPOLITANA DO RIO DE JANEIRO
# Andaraí            METROPOLITANA DO RIO DE JANEIRO
# ...                                            ...
# Vila Valqueire     METROPOLITANA DO RIO DE JANEIRO
# Vila da Penha      METROPOLITANA DO RIO DE JANEIRO
# Vista Alegre       METROPOLITANA DO RIO DE JANEIRO
# Zumbi              METROPOLITANA DO RIO DE JANEIRO
# Água Santa         METROPOLITANA DO RIO DE JANEIRO
#
# [160 rows x 13 columns]

# %%
mapa_rio = folium.Map(location = [-22, -43],
                      zoom_start = 8,
                      tiles = 'cartodbpositron')

folium.GeoJson(bairros_rio).add_to(mapa_rio)

mapa_rio

# %%
cidade = cidade_rio.dissolve(by = 'NM_MUNICIP')
cidade
# Out:
#                                                          geometry     ID  \
# NM_MUNICIP
# RIO DE JANEIRO  MULTIPOLYGON (((-43.69721 -22.98559, -43.69753...  56651
#
#                      CD_GEOCODI    TIPO    CD_GEOCODB NM_BAIRRO   CD_GEOCODS  \
# NM_MUNICIP
# RIO DE JANEIRO  330455705080006  URBANO  330455705005   Catumbi  33045570508
#
#                   NM_SUBDIST CD_GEOCODD      NM_DISTRIT CD_GEOCODM  \
# NM_MUNICIP
# RIO DE JANEIRO  RIO COMPRIDO  330455705  RIO DE JANEIRO    3304557
#
#                       NM_MICRO                          NM_MESO
# NM_MUNICIP
# RIO DE JANEIRO  RIO DE JANEIRO  METROPOLITANA DO RIO DE JANEIRO

# %%
mapa_rio = folium.Map(location = [-22, -43],
                      zoom_start = 8,
                      tiles = 'cartodbpositron')

folium.GeoJson(cidade).add_to(mapa_rio)

mapa_rio
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf42468ed8689241e116342dc763b394 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf42468ed8689241e116342dc763b394&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf42468ed8689241e116342dc763b394 = L.map(
#                 &quot;map_cf42468ed8689241e116342dc763b394&quot;,
#                 {
#                     center: [-22.0, -43.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee0d7a2838b94e819ca1e0c4b790b7db = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf42468ed8689241e116342dc763b394);
#
#
#
#         function geo_json_6f17485c7280e278bdfe51e60fc8481e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6f17485c7280e278bdfe51e60fc8481e = L.geoJson(null, {
#                 onEachFeature: geo_json_6f17485c7280e278bdfe51e60fc8481e_onEachFeature,
#
#         });
#
#         function geo_json_6f17485c7280e278bdfe51e60fc8481e_add (data) {
#             geo_json_6f17485c7280e278bdfe51e60fc8481e
#                 .addData(data)
#                 .addTo(map_cf42468ed8689241e116342dc763b394);
#         }
#             geo_json_6f17485c7280e278bdfe51e60fc8481e_add({&quot;bbox&quot;: [-43.79653853090349, -23.0828926973403, -43.09903940038369, -22.746020285810395], &quot;features&quot;: [{&quot;bbox&quot;: [-43.79653853090349, -23.0828926973403, -43.09903940038369, -22.746020285810395], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-43.6972106498898, -22.9855859887124], [-43.697531114692794, -22.985870846315002], [-43.69891979550569, -22.986084489516998], [-43.69915653515709, -22.986211622733492], [-43.6995132488445, -22.986274394585394], [-43.700395929813894, -22.986337522292096], [-43.7007369389884, -22.985715682032797], [-43.700696820261996, -22.9850136043207], [-43.701559372879686, -22.983990576797197], [-43.701990276875094, -22.983143375721596], [-43.7024780043853, -22.9821844538371], [-43.7027032686897, -22.9817415613065], [-43.703257998120094, -22.980650906833198], [-43.70392637773779, -22.9793368045339], [-43.70484935506819, -22.977979484930295], [-43.70562004484279, -22.976846117614798], [-43.706647907689, -22.975334554605695], [-43.7066544511336, -22.975324931893], [-43.707825676038894, -22.974124130601297], [-43.70907367726139, -22.972836529589898], [-43.709078275393594, -22.972839899949697], [-43.710626205048, -22.9712528811626], [-43.710829185739, -22.971152659446396], [-43.7138357031607, -22.969668191469395], [-43.714971611311, -22.970138685969594], [-43.71511570506969, -22.9701983697749], [-43.7172257355422, -22.9710723468937], [-43.71772721962229, -22.9719750182379], [-43.7181083475232, -22.972215730596396], [-43.7188304845985, -22.972837570855695], [-43.719773274669095, -22.973599826657498], [-43.720146318742195, -22.973541833386193], [-43.71999392766439, -22.9729779863981], [-43.71955295964909, -22.9725663470241], [-43.719532562310704, -22.972235789959598], [-43.7202747587492, -22.9717142465163], [-43.72082982446979, -22.971307603713996], [-43.71999392766439, -22.970390328544795], [-43.71931407032419, -22.970498755463595], [-43.71875291150319, -22.9701762487138], [-43.7187467211691, -22.9696561643864], [-43.7190435039758, -22.968503908154], [-43.71941395278249, -22.967065644425098], [-43.71947794040659, -22.966993485870397], [-43.72099715506819, -22.965280274357795], [-43.723328069453785, -22.962216673976293], [-43.72694801283549, -22.959148821843094], [-43.73048604649459, -22.957160642574394], [-43.732644801475104, -22.955399552985], [-43.734235463039695, -22.954149747469998], [-43.7381553076097, -22.9519909924894], [-43.73963235049109, -22.9509684243407], [-43.741052584030996, -22.950002665533695], [-43.74223081351579, -22.949124987358296], [-43.7434090430006, -22.948247309182896], [-43.745799890174396, -22.947924929151597], [-43.74641778758989, -22.9471267663372], [-43.7464686034366, -22.947082814560396], [-43.7467735305205, -22.946819076218794], [-43.747382291603, -22.946795433345194], [-43.747856217107795, -22.946976603673995], [-43.748356268571, -22.9469558400493], [-43.7488838913812, -22.946829676400498], [-43.7497694124155, -22.946367373661495], [-43.750160412496, -22.945981554633796], [-43.75038282546879, -22.944959882179496], [-43.75047113109379, -22.943619783195693], [-43.751442851750994, -22.942499472754193], [-43.752467981526095, -22.941717431708597], [-43.7534635917839, -22.9409763614264], [-43.7565196515026, -22.939332601807095], [-43.760083713464795, -22.9377318477
